# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import os
import zipfile

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Dataset/15000000to15249999_BlockTransaction.zip"

# %%
export_path = "/content/drive/MyDrive/Colab Notebooks/Dataset/15000000to15249999/15000000to15249999_BlockTransaction_chunk_"

# %%
csv_file_name = '15000000to15249999_BlockTransaction.csv'

# %%
chunk_size=2000000

# %%
def export_chunk(df, count):
  df.to_csv(export_path + f'{i}.csv', index=False)

# %%
with zipfile.ZipFile(path , 'r') as zip_ref:
    if csv_file_name in zip_ref.namelist():
        with zip_ref.open(csv_file_name) as csv_file:
            chunks = pd.read_csv(csv_file, chunksize=chunk_size)
            for i, chunk in enumerate(chunks):
                # Xử lý chunk tại đây, ví dụ: in 5 dòng đầu tiên của mỗi chunk
                print(f"Chunk {i}:")
                export_chunk(chunk, i)
    else:
        print("Không tìm thấy tệp trong zip.")
# Out:
# <ipython-input-19-fafd75089dd8>:5: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(chunks):
# Chunk 0:
# <ipython-input-19-fafd75089dd8>:5: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(chunks):
# Chunk 1:
# <ipython-input-19-fafd75089dd8>:5: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(chunks):
# Chunk 2:
# <ipython-input-19-fafd75089dd8>:5: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(chunks):
# Chunk 3:
# Chunk 4:
# <ipython-input-19-fafd75089dd8>:5: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(chunks):
# Chunk 5:
# Chunk 6:
# Chunk 7:
# Chunk 8:
# ...
