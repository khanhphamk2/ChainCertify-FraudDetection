# %%
import pandas as pd
import numpy as np

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Data/Blocks_Address/"

# %%
df_sample = pd.read_csv(path + "15000000to15999999_address.csv")

# %%
df_sample.head()
# Out:
#                                       Address
# 0  0xcefcca169357a18eb8c3f230f92b58562e48cae5
# 1  0x42d17b7f3532ec2f7c4e4e5e239baa476846e2cd
# 2  0x15a7ac655900c3e5103e1824971b515c6a0487df
# 3  0x83c553bc43f4062c1516d1b65de10f5e8d225d70
# 4  0x2db3048488f773eef11f90091832f25b16270cd1
